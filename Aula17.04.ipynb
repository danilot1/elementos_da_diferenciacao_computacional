# %%
from sympy import*

# %%
x = Symbol('x')
y= Symbol('y')
h= Symbol('h')
t = Symbol('t')

# %%
eq2= x**3
eq3=(x+h)**3
q=(eq3-eq2)/h
limite1=limit(q,h,0)
print(limite1)
# Out:
# 3*x**2

# %%
eq5 = 2*x-3
limite5=limit(eq5,x,2)
print(limite5)
# Out:
# 1

# %%
eq6 =3*x**2-2
limite6=limit(eq6,x,0)
print(limite6)
# Out:
# -2

# %% [markdown]
# Primeira questão

# %%
eqa=(x**0.5-2)/(x-4)
limitea=limit(eqa,x,4)

print(limitea)
# Out:
# 1/4

# %%
eqb =((t**2+9)**0.5-3)/(t**2)
limiteb = limit(eqb,t,0)
print(limiteb)
# Out:
# 1/6

# %%
eqc =((h+1)**(1/3)-1)/h
limitec = limit(eqc,h,0)
print(limitec)
# Out:
# 1/3

# %%
eqd =(4*x**2 - 2*x**3 +5*x -5)/(-x**2+x-3)
limited =limit(eqd,x,0)
print(limited)
# Out:
# 5/3

# %%
pi = 3.14
eqe = 2*pi - pi**2
limitee = limit(eqe,x,4)
print(limitee)
# Out:
# -3.57960000000000

# %% [markdown]
# Segunda questão

# %%
eqa= x**1/3 #f(x)
eqa1 = (x+h)**1/3 #f(x+h)
q = (eqa1 -eqa)/h
limitea =limit(q,h,0)
print(limitea)
# Out:
# 1/3

# %%
eqb = x**3 #f(x)
eqb1 = (x+h)**3 #f(x+h)
q = (eqb1-eqb)/h 
limiteb = limit(q,h,0)
print(limiteb)
# Out:
# 3*x**2

# %%
eqc = (2*x-1)**1/2 #f(x)
eqc1 = (2*(x+h)-1)**1/2 #f(x+h)
q = (eqc1 -eqc)/h
limitec = limit(q,h,0)
print(limitec)
# Out:
# 1

# %%
eqd = (2+x)/(3-x) #f(x)
eqd1 = (2+(x+h))/(3-(x+h)) #f(x+h)
q= (eqd1-eqd)/h
limited = limit(q,h,0)
print(limited)
# Out:
# (5*x - 15)/(x**3 - 9*x**2 + 27*x - 27)
